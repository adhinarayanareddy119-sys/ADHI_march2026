# %% [markdown]
# <a href="https://colab.research.google.com/github/adhinarayanareddy119-sys/ADHI_march2026/blob/main/float_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577

# %%
list1=[3.14,2.718,1.618,0.577]
list2=sum(list1)
list3=list2/len(list1)
print(f"the average of sum:{list3}")
# Out:
# the average of sum:2.01325

# %% [markdown]
# # Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)

# %%
fahrenheit_value=98.6
converted=fahrenheit_value*9/5+35
print(f"after converting fahrenheit to celsius:{converted}")
# Out:
# after converting fahrenheit to celsius:212.48

# %% [markdown]
# # Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years

# %%
money=1000
finding_intrest=(1000*5.5*3)/100
intrest=money+finding_intrest
print(f"after calculating the compound intrest:{finding_intrest}+{money}={intrest}")
# Out:
# after calculating the compound intrest:165.0+1000=1165.0

# %% [markdown]
# # Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2

# %%
import math
a=3.5
b=4.2
c=math.sqrt(a**2+b**2)
print(f"the another side :{c}")
# Out:
# the another side :5.4671747731346585

# %% [markdown]
# # Question 5: Calculate the volume of a sphere with radius 7.8

# %%
import math
radius=7.8
volume=4/3*math.pi*(7.8**3)
print(f"the volume of a sphere with radius:{volume}")
# Out:
# the volume of a sphere with radius:1987.798769261791

# %% [markdown]
# # Question 6: Round 3.14159 to 3 decimal places

# %%
value=3.14159
value1=(round(value,3))
print(f"after rounded the value with 3 : {value1}")
# Out:
# after rounded the value with 3 : 3.142

# %% [markdown]
# # Question 7: Calculate the percentage: 45 out of 67

# %%
num1=45
num2=67
percentage=(num1/num2)*100
print(f"the percentage value: {percentage}")
# Out:
# the percentage value: 67.16417910447761

# %%
num1=45
num2=67
percentage=(num1/num2)
print(f"the percentage value:{percentage}")
# Out:
# the percentage value:0.6716417910447762

# %% [markdown]
# # Question 8: Find the square root of 23.456

# %%
import math
value=23.456
value1=math.sqrt(value)

print(f"the square root 23.456:{value1}")
# Out:
# the square root 23.456:4.843139477652899

# %% [markdown]
# # Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years

# %%
principal=2500
rate=6.5
time=2.5
intrest=(principal*6.5*2.5)/100
print(f"simple intrest:{intrest}")
# Out:
# simple intrest:406.25

# %% [markdown]
# # Question 10: Convert 45.7 degrees to radians

# %%
degree=45.7
pi=3.141
radians=degree*(pi/180)
print(f"after converting degrees to radians:{radians}")
# Out:
# after converting degrees to radians:0.7974650000000001
